# %%
import pandas as pd
import plotnine as p9

# %% [markdown]
# 1. Explore the following four time series: `Bricks` from `aus_production`, `Lynx` from `pelt`, `Close` from `gafa_stock`, `Demand` from `vic_elec`.
#
#     What is the time interval of each series?
#     Produce a time plot of each series.
#     For the last plot, modify the axis labels and title.

# %%
aus_production = pd.read_csv('data/aus-production.csv', delimiter=';')
bricks = aus_production['Bricks']
gafa_stock = pd.read_csv('data/GOOGL.csv')
google_close = gafa_stock['Close']

# %%
(p9.ggplot(data=aus_production, mapping=p9.aes(x='Quarter', y='Bricks', group=1)) + p9.geom_line())
# Out:
# /Users/lcsontos/Library/Caches/pypoetry/virtualenvs/notebooks-ar5e71fk-py3.11/lib/python3.11/site-packages/plotnine/geoms/geom_path.py:98: PlotnineWarning: geom_path: Removed 20 rows containing missing values.
# <Figure Size: (640 x 480)>

# %%
(p9.ggplot(data=gafa_stock, mapping=p9.aes(x='Date', y='Close', group = 1))
 + p9.geom_line()
 + p9.labs(x = 'Date', y = 'Closing price', title = 'GOOG closing price')
)
# Out:
# <Figure Size: (640 x 480)>
